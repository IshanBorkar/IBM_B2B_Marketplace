# %% [markdown]
# # 1) Import the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os, sys, datetime, re , glob
from os import listdir
import math
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # 2) Load the Chemical_Hazardous Datasets

# %%
data_path = "D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous"
filenames = os.listdir(data_path)
print(filenames)
# Out:
# ['training_data_uc1_chemical_hazardous_1.xlsx', 'training_data_uc1_chemical_hazardous_2.xlsx']

# %%
df_chemical_hazardous_1 = pd.read_excel(data_path +"/" +"training_data_uc1_chemical_hazardous_1.xlsx")
df_chemical_hazardous_1.head(10)
# Out:
#           Manufacturer  Manufacturer Part Number  \
# 0              Chemicon                      NaN
# 1              Chemicon                      NaN
# 2              Chemicon                      NaN
# 3            Centrifree                      NaN
# 4       Millipore Sigma                      NaN
# 5              Chemicon                      NaN
# 6              Chemicon                      NaN
# 7  Hayes Separation Inc                      NaN
# 8       Millipore Sigma                      NaN
# 9       Millipore Sigma                      NaN
#
#                                   Item Name  \
# 0                          POLIO 1  MAB-1ML
# 1                          POLIO 2  MAB-1ML
# 2                          POLIO 3  MAB-1ML
# 3  CENTRIFREE ULTRAFILTRATION DEVICE WITH &
# 4                 HUMAN METAPNEUMOVIRUS DFA
# 5                           ECHO  BLEND-2ML
# 6                        RABIES DFA REAGENT
# 7                     HAYESEP A 60/80  75CC
# ...

# %%
df_chemical_hazardous_2 = pd.read_excel(data_path +"/" +"training_data_uc1_chemical_hazardous_2.xlsx")
df_chemical_hazardous_2.head(10)
# Out:
#     Manufacturer  Manufacturer Part Number  \
# 0  MilliporeSigma              101915-250G
# 1  MilliporeSigma               101915-50G
# 2  MilliporeSigma            1019202-200MG
# 3  MilliporeSigma            1019406-150MG
# 4  MilliporeSigma            1019417-100MG
# 5  MilliporeSigma             1019428-50MG
# 6  MilliporeSigma            1019494-100MG
# 7  MilliporeSigma            1019508-300MG
# 8  MilliporeSigma            1019701-500MG
# 9  MilliporeSigma             1019712-30MG
#
#                                            Item Name  Description  \
# 0                            2 4-DIAMINOTOLUENE  98%          NaN
# 1                            2 4-DIAMINOTOLUENE  98%          NaN
# 2  AMCINONIDE  UNITED STATES PHARMACOPEIA (USP) R...          NaN
# 3  AMIFOSTINE  UNITED STATES PHARMACOPEIA (USP) R...          NaN
# 4  AMIFOSTINE DISULFIDE  UNITED STATES PHARMACOPE...          NaN
# 5  AMIFOSTINE THIOL  UNITED STATES PHARMACOPEIA (...          NaN
# ...

# %%
print(df_chemical_hazardous_1.shape)
print(df_chemical_hazardous_2.shape)
# Out:
# (99999, 19)
# (53520, 19)

# %%
print(df_chemical_hazardous_1.size)
print(df_chemical_hazardous_2.size)
# Out:
# 1899981
# 1016880

# %% [markdown]
# ## 2.0) Reduce the above dataset to half

# %%
df_chemical_hazardous_1_half = df_chemical_hazardous_1.iloc[0:50000]
df_chemical_hazardous_2_half = df_chemical_hazardous_2.iloc[0:26760]

# %%
df_chemical_hazardous_1_half.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_half/training_data_uc1_chemical_hazardous_1_half.xlsx')
df_chemical_hazardous_2_half.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_half/training_data_uc1_chemical_hazardous_2_half.xlsx')

# %% [markdown]
# ## 2.1) Reduce the dataframe and save it in the excel

# %%
df_chemical_hazardous_1_10k = df_chemical_hazardous_1.iloc[0:10000]
df_chemical_hazardous_2_10k = df_chemical_hazardous_2.iloc[0:10000]

# %%
df_chemical_hazardous_1_10k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_10K/training_data_uc1_chemical_hazardous_1_10k.xlsx')
df_chemical_hazardous_2_10k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_10K/training_data_uc1_chemical_hazardous_2_10k.xlsx')

# %% [markdown]
# ## 2.2) Try the same for different datasets of different sizes

# %%
df_chemical_hazardous_1_25k = df_chemical_hazardous_1.iloc[0:25000]
df_chemical_hazardous_2_25k = df_chemical_hazardous_2.iloc[0:25000]
df_chemical_hazardous_1_25k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_25K/training_data_uc1_chemical_hazardous_1_25k.xlsx')
df_chemical_hazardous_2_25k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_25K/training_data_uc1_chemical_hazardous_2_25k.xlsx')

# %%
df_chemical_hazardous_1_60k = df_chemical_hazardous_1.iloc[0:60000]
df_chemical_hazardous_2_60k = df_chemical_hazardous_2.iloc[0:60000]
df_chemical_hazardous_1_60k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_60K/training_data_uc1_chemical_hazardous_1_60k.xlsx')
df_chemical_hazardous_2_60k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_60K/training_data_uc1_chemical_hazardous_2_60k.xlsx')

# %%
df_chemical_hazardous_1_90k = df_chemical_hazardous_1.iloc[0:90000]
df_chemical_hazardous_2_90k = df_chemical_hazardous_2.iloc[0:90000]
df_chemical_hazardous_1_90k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_90K/training_data_uc1_chemical_hazardous_1_90k.xlsx')
df_chemical_hazardous_2_90k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_90K/training_data_uc1_chemical_hazardous_2_90k.xlsx')

# %%
df_chemical_hazardous_1_1L = df_chemical_hazardous_1.iloc[0:100000]
df_chemical_hazardous_2_1L = df_chemical_hazardous_2.iloc[0:100000]
df_chemical_hazardous_1_1L.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_1L/training_data_uc1_chemical_hazardous_1_1L.xlsx')
df_chemical_hazardous_2_1L.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Chemical_Hazardous_1L/training_data_uc1_chemical_hazardous_2_1L.xlsx')

# %% [markdown]
# # 3) Load the Restricted_Prohibited Datasets

# %%
data_path1 = "D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited"
filenames1 = os.listdir(data_path1)
print(filenames1)
# Out:
# ['training_data_uc1_restricted_prohibited_1.xlsx', 'training_data_uc1_restricted_prohibited_2.xlsx']

# %%
df_restricted_prohibited_1 = pd.read_excel(data_path1 +"/" +"training_data_uc1_restricted_prohibited_1.xlsx")
df_restricted_prohibited_1.head(10)
# Out:
#    Manufacturer  Manufacturer Part Number  \
# 0  Kim Crawford                       NaN
# 1         Meiomi                      NaN
# 2          Stone                      NaN
# 3        Bulleit                      NaN
# 4       Jim Beam                      NaN
# 5       Jim Beam                      NaN
# 6     First Call                      NaN
# 7          Lobos                      NaN
# 8        Dalmore                      NaN
# 9      De Venoge                      NaN
#
#                                    Item Name  \
# 0                            Sauvignon Blanc
# 1                         Meiomi Pinot Noir
# 2                            Stone Hazy IPA
# 3                           Bulleit Bourbon
# 4               Jim Beam Black (black label)
# 5            Jim Beam Original (white label)
# 6  First Call Kentucky Straight Rye Whiskey
# 7            Lobos 1707 Extra Anejo Tequila
# 8                     Dalmore King Alex III
# ...

# %%
df_restricted_prohibited_2 = pd.read_excel(data_path1 +"/" +"training_data_uc1_restricted_prohibited_2.xlsx")
df_restricted_prohibited_2.head(10)
# Out:
#   Manufacturer   Manufacturer Part Number  \
# 0       SEPHORA                       NaN
# 1       SEPHORA                       NaN
# 2       SEPHORA                       NaN
# 3       SEPHORA                       NaN
# 4       SEPHORA                       NaN
# 5       SEPHORA                       NaN
# 6       SEPHORA                       NaN
# 7       SEPHORA                       NaN
# 8       SEPHORA                       NaN
# 9       SEPHORA                       NaN
#
#                                            Item Name  \
# 0  SEPHORA - PALETTE DES RVES GLACS - PALETTE YEU...
# 1  SEPHORA - PALETTE DES RVES GLACS - PALETTE YEU...
# 2  SEPHORA - PALETTE DES RVES GLACS - PALETTE YEU...
# 3           SEPHORA - BAGUETTE DE GLOSS / GLOSS WAND
# 4  SEPHORA - DUO LEVRES ET JOUES / LIP AND CHEEK DUO
# 5  SEPHORA - DUO LEVRES ET JOUES / LIP AND CHEEK DUO
# 6  SEPHORA - LA BAGUETTE MAGIQUE DE L'HIVER / WIN...
# 7  SEPHORA - LA BAGUETTE MAGIQUE DE L'HIVER / WIN...
# ...

# %%
print(df_restricted_prohibited_1.shape)
print(df_restricted_prohibited_2.shape)
# Out:
# (49999, 19)
# (28419, 19)

# %%
print(df_restricted_prohibited_1.size)
print(df_restricted_prohibited_2.size)
# Out:
# 949981
# 539961

# %% [markdown]
# ## 3.0) Reduce the above dataset to half

# %%
df_restricted_prohibited_1_half = df_restricted_prohibited_1.iloc[0:25000]
df_restricted_prohibited_2_half = df_restricted_prohibited_2.iloc[0:14210]

# %%
df_restricted_prohibited_1_half.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_half/training_data_uc1_restricted_prohibited_1_half.xlsx')
df_restricted_prohibited_2_half.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_half/training_data_uc1_restricted_prohibited_2_half.xlsx')

# %% [markdown]
# ## 3.1) Reduce the dataframe and save it in the excel

# %%
df_restricted_prohibited_1_10k = df_restricted_prohibited_1.iloc[0:10000]
df_restricted_prohibited_2_10k = df_restricted_prohibited_2.iloc[0:10000]

# %%
df_restricted_prohibited_1_10k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_10K/training_data_uc1_restricted_prohibited_1_10k.xlsx')
df_restricted_prohibited_2_10k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_10K/training_data_uc1_restricted_prohibited_2_10k.xlsx')

# %% [markdown]
# ## 3.2) Try the same for different datasets of different sizes

# %%
df_restricted_prohibited_1_25k = df_restricted_prohibited_1.iloc[0:25000]
df_restricted_prohibited_2_25k = df_restricted_prohibited_2.iloc[0:25000]
df_restricted_prohibited_1_25k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_25K/training_data_uc1_restricted_prohibited_1_25k.xlsx')
df_restricted_prohibited_2_25k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_25K/training_data_uc1_restricted_prohibited_2_25k.xlsx')

# %%
df_restricted_prohibited_1_60k = df_restricted_prohibited_1.iloc[0:60000]
df_restricted_prohibited_2_60k = df_restricted_prohibited_2.iloc[0:60000]
df_restricted_prohibited_1_60k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_60K/training_data_uc1_restricted_prohibited_1_60k.xlsx')
df_restricted_prohibited_2_60k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_60K/training_data_uc1_restricted_prohibited_2_60k.xlsx')

# %%
df_restricted_prohibited_1_90k = df_restricted_prohibited_1.iloc[0:90000]
df_restricted_prohibited_2_90k = df_restricted_prohibited_2.iloc[0:90000]
df_restricted_prohibited_1_90k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_90K/training_data_uc1_restricted_prohibited_1_90k.xlsx')
df_restricted_prohibited_2_90k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_90K/training_data_uc1_restricted_prohibited_2_90k.xlsx')

# %%
df_restricted_prohibited_1_1L = df_restricted_prohibited_1.iloc[0:100000]
df_restricted_prohibited_2_1L = df_restricted_prohibited_2.iloc[0:100000]
df_restricted_prohibited_1_1L.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_1L/training_data_uc1_restricted_prohibited_1_1L.xlsx')
df_restricted_prohibited_2_1L.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Restricted_Prohibited_1L/training_data_uc1_restricted_prohibited_2_1L.xlsx')

# %% [markdown]
# # 4) Load the Neither Category Datasets

# %%
data_path2 = "D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category"
filenames2 = os.listdir(data_path2)
print(filenames2)
# Out:
# ['training_data_uc1_neither_category_1.xlsx', 'training_data_uc1_neither_category_2.xlsx']

# %%
df_neither_1 = pd.read_excel(data_path2 +"/" +"training_data_uc1_neither_category_1.xlsx")
df_neither_1.head(10)
# Out:
#   Manufacturer  Manufacturer Part Number  \
# 0            3M                    LX500
# 1            3M                    LX550
# 2      Evoluent              KBC-EVM003R
# 3    Kensington                    64020
# 4    Kensington                 K64675EU
# 5         Lindy                    32569
# 6         Lindy                    32572
# 7            3M                  MW311MX
# 8         Apple                MD463ZM/A
# 9         Apple                 MC747B/B
#
#                                            Item Name  \
# 0   3M LX500 Adjustable Notebook Riser Stand (Black)
# 1  3M LX550 Adjustable Riser/Stand for Laptop/Not...
# 2               Evoluent 3 Vertical Mouse Right Hand
# 3  Kensington MicroSaver Laptop Lock - Keyed Diff...
# 4           Kensington Combination Ultra Laptop Lock
# 5                Lindy (2 Port) VGA Splitter (Black)
# 6                Lindy (4 Port) VGA Splitter (White)
# 7  3M Precise MW311MX (22.1cm x 23.4cm) Optical M...
# ...

# %%
df_neither_2 = pd.read_excel(data_path2 +"/" +"training_data_uc1_neither_category_2.xlsx")
df_neither_2.head(10)
# Out:
#     Manufacturer  Manufacturer Part Number  \
# 0  O'Reilly Media            9781491963043
# 1  O'Reilly Media            9781491986363
# 2  O'Reilly Media            9781491989388
# 3  O'Reilly Media            9781449316563
# 4  O'Reilly Media            9781491910658
# 5  O'Reilly Media            9780596003555
# 6  O'Reilly Media            9781491900635
# 7  O'Reilly Media            9780596003227
# 8  O'Reilly Media            9781449339197
# 9  O'Reilly Media            9781449322137
#
#                                            Item Name  \
# 0  Applied Text Analysis with Python: Enabling La...
# 1  Building Evolutionary Architectures: Support C...
# 2  Machine Learning with Python Cookbook: Practic...
# 3  Enabling Programmable Self with Healthvault: A...
# 4  Getting Started with Openbts: Build Open Sourc...
# 5              Xsl-Fo: Making XML Look Good in Print
# 6  Salt Essentials: Getting Started with Automati...
# 7  Radius: Securing Public Access to Private Reso...
# ...

# %%
print(df_neither_1.shape)
print(df_neither_2.shape)
# Out:
# (99999, 19)
# (61452, 19)

# %%
print(df_neither_1.size)
print(df_neither_2.size)
# Out:
# 1899981
# 1167588

# %% [markdown]
# ## 4.0) Reduce the dataset to half

# %%
df_neither_1_half = df_neither_1.iloc[0:50000]
df_neither_2_half = df_neither_2.iloc[0:30726]

# %%
df_neither_1_half.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_half/training_data_uc1_neither_category_1_half.xlsx')
df_neither_2_half.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_half/training_data_uc1_neither_category_2_half.xlsx')

# %% [markdown]
# ## 4.1) Reduce the dataframe and save it in the excel

# %%
df_neither_1_10k = df_neither_1.iloc[0:10000]
df_neither_2_10k = df_neither_2.iloc[0:10000]

# %%
df_neither_1_10k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_10K/training_data_uc1_neither_category_1_10k.xlsx')
df_neither_2_10k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_10K/training_data_uc1_neither_category_2_10k.xlsx')

# %% [markdown]
# ## 4.2) Try the same for different datasets of different sizes

# %%
df_neither_1_25k = df_neither_1.iloc[0:25000]
df_neither_2_25k = df_neither_2.iloc[0:25000]
df_neither_1_25k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_25K/training_data_uc1_neither_category_1_25k.xlsx')
df_neither_2_25k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_25K/training_data_uc1_neither_category_2_25k.xlsx')

# %%
df_neither_1_60k = df_neither_1.iloc[0:60000]
df_neither_2_60k = df_neither_2.iloc[0:60000]
df_neither_1_60k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_60K/training_data_uc1_neither_category_1_60k.xlsx')
df_neither_2_60k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_60K/training_data_uc1_neither_category_2_60k.xlsx')

# %%
df_neither_1_90k = df_neither_1.iloc[0:90000]
df_neither_2_90k = df_neither_2.iloc[0:90000]
df_neither_1_90k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_90K/training_data_uc1_neither_category_1_90k.xlsx')
df_neither_2_90k.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_90K/training_data_uc1_neither_category_2_90k.xlsx')

# %%
df_neither_1_1L = df_neither_1.iloc[0:100000]
df_neither_2_1L = df_neither_2.iloc[0:100000]
df_neither_1_1L.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_1L/training_data_uc1_neither_category_1_1L.xlsx')
df_neither_2_1L.to_excel('D:/IBM_B2B_C_Onboarding/UC1/Data/Training_data_files/Neither_Category_1L/training_data_uc1_neither_category_2_1L.xlsx')
