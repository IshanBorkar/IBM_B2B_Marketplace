# %% [markdown]
# # 1) Import the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os, sys, datetime, re , glob
from os import listdir
import math
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # 2) Include the directory where CIV Training data from Gfk is present

# %%
data_path ="D:\IBM_B2B_C_Onboarding\CIV_Training_Data_from_GfK\GFK_Data"
filenames = os.listdir(data_path)
print(filenames)
# Out:
# ['GFKProducts_000_2022_11_09_17_16_22.xlsx', 'GFKProducts_001_2022_11_09_17_16_22.xlsx', 'GFKProducts_002_2022_11_09_17_16_22.xlsx', 'GFKProducts_003_2022_11_09_17_16_22.xlsx', 'GFKProducts_004_2022_11_09_17_16_22.xlsx', 'GFKProducts_005_2022_11_09_17_16_22.xlsx', 'GFKProducts_006_2022_11_09_17_16_22.xlsx', 'GFKProducts_007_2022_11_09_17_16_22.xlsx', 'GFKProducts_008_2022_11_09_17_16_22.xlsx', 'GFKProducts_009_2022_11_09_17_16_22.xlsx']

# %% [markdown]
# # 3) Load all the GFK excel files

# %%
df_Gfk1 = pd.read_excel(data_path +"/" +"GFKProducts_000_2022_11_09_17_16_22.xlsx")
df_Gfk1.head()
# Out:
#     ProductID           Manufacturer Manufacturer Part Number  \
# 0  1064679894             Kar's Nuts                  SN08235
# 1  1010043930  Starbucks Corporation                   197861
# 2  1010041979     ConAgra Foods, Inc                    55584
# 3  1010041978     ConAgra Foods, Inc                    55280
# 4  1010042104             Nestle S.A                    12612
#
#   Manufacturer Website Address  Brand Name Product Model  \
# 0      http://www.karsnuts.com       Kar's           NaN
# 1     http://www.starbucks.com   Starbucks           NaN
# 2  http://www.conagrafoods.com  Swiss Miss           NaN
# 3  http://www.conagrafoods.com  Swiss Miss           NaN
# 4     http://www.nestleusa.com      Nestle           NaN
#
#                                       Product Name  \
# 0               Roasted & Salted Sunflower Kernels
# 1                                Gourmet Hot Cocoa
# 2  Milk Chocolate No Sugar Added Cocoa Mix Packets
# ...

# %%
df_Gfk2 = pd.read_excel(data_path +"/" +"GFKProducts_001_2022_11_09_17_16_22.xlsx")
df_Gfk2.head()
# Out:
#     ProductID             Manufacturer Manufacturer Part Number  \
# 0  1014572270          Agptek.com, Inc   Acer Aspire One AOD250
# 1  1014532810  Battery Technology, Inc                  PA-CF52
# 2  1014548929          Agptek.com, Inc            Thinkpad-T400
# 3  1014961501   Axiom Memory Solutions               57Y4536-AX
# 4  1014942218              Miccus, Inc                  CBFI-01
#
#   Manufacturer Website Address Brand Name Product Model  \
# 0        http://www.agptek.com     Agptek           NaN
# 1   http://www.batterytech.com        BTI           NaN
# 2        http://www.agptek.com     Agptek           NaN
# 3   http://www.axiommemory.com      Axiom           NaN
# 4        http://www.miccus.com     Miccus       CBFI-01
#
#                                         Product Name  \
# 0  Acer Aspire One 10.1 inch AOD150 AOD250 UM08A3...
# 1                                   Notebook Battery
# 2  Lenovo IBM ThinkPad R61 R61i T61 T61p R400 T40...
# ...

# %%
df_Gfk3 = pd.read_excel(data_path +"/" +"GFKProducts_002_2022_11_09_17_16_22.xlsx")
df_Gfk3.head()
# Out:
#     ProductID             Manufacturer Manufacturer Part Number  \
# 0  1022544172  Battery Technology, Inc             LTBT21432M2R
# 1  1022558552  Battery Technology, Inc             LTBT33274M2R
# 2  1022562783  Battery Technology, Inc             LTBT38137M2R
# 3  1022588649  Battery Technology, Inc             LTBT52986M2R
# 4  1022556159  Battery Technology, Inc             LTBT30880M2R
#
#   Manufacturer Website Address Brand Name  Product Model      Product Name  \
# 0   http://www.batterytech.com        BTI            NaN  Notebook Battery
# 1   http://www.batterytech.com        BTI            NaN  Notebook Battery
# 2   http://www.batterytech.com        BTI            NaN  Notebook Battery
# 3   http://www.batterytech.com        BTI            NaN  Notebook Battery
# 4   http://www.batterytech.com        BTI            NaN  Notebook Battery
#
#   Marketing Information Country of Origin    UNSPSC  ...  Density  \
# ...

# %%
df_Gfk4 = pd.read_excel(data_path +"/" +"GFKProducts_003_2022_11_09_17_16_22.xlsx")
df_Gfk4.head()
# Out:
#     ProductID             Manufacturer Manufacturer Part Number  \
# 0  1022578736  Battery Technology, Inc             LTBT41537M2R
# 1  1022552658  Battery Technology, Inc             LTBT27379M2R
# 2  1022533430  Battery Technology, Inc             LTBT11214M2R
# 3  1022536189  Battery Technology, Inc             LTBT14947M2R
# 4  1022532587  Battery Technology, Inc             LTBT07028M2R
#
#   Manufacturer Website Address Brand Name Product Model      Product Name  \
# 0   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 1   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 2   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 3   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 4   http://www.batterytech.com        BTI           NaN  Notebook Battery
#
#   Marketing Information Country of Origin    UNSPSC  ...  Density  \
# ...

# %%
df_Gfk5 = pd.read_excel(data_path +"/" +"GFKProducts_004_2022_11_09_17_16_22.xlsx")
df_Gfk5.head()
# Out:
#     ProductID             Manufacturer Manufacturer Part Number  \
# 0  1022526731  Battery Technology, Inc             GW0190OEMA2B
# 1  1022580506  Battery Technology, Inc             LTBT44060M2R
# 2  1022537904  Battery Technology, Inc             LTBT16977M2R
# 3  1022581577  Battery Technology, Inc             LTBT45131M2R
# 4  1022562646  Battery Technology, Inc             LTBT38000M2R
#
#   Manufacturer Website Address Brand Name Product Model      Product Name  \
# 0   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 1   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 2   http://www.batterytech.com        BTI           NaN   Netbook Battery
# 3   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 4   http://www.batterytech.com        BTI           NaN  Notebook Battery
#
#   Marketing Information Country of Origin    UNSPSC  ...  Density  \
# ...

# %%
df_Gfk6 = pd.read_excel(data_path +"/" +"GFKProducts_005_2022_11_09_17_16_22.xlsx")
df_Gfk6.head()
# Out:
#     ProductID             Manufacturer Manufacturer Part Number  \
# 0  1022576884  Battery Technology, Inc             LTBT39561M2R
# 1  1022542891  Battery Technology, Inc             LTBT20151M2R
# 2  1022529186  Battery Technology, Inc             LTBT00773M2R
# 3  1022535571  Battery Technology, Inc             LTBT13843M2R
# 4  1022532612  Battery Technology, Inc             LTBT07178M2R
#
#   Manufacturer Website Address Brand Name Product Model      Product Name  \
# 0   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 1   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 2   http://www.batterytech.com        BTI           NaN   Netbook Battery
# 3   http://www.batterytech.com        BTI           NaN   Netbook Battery
# 4   http://www.batterytech.com        BTI           NaN  Notebook Battery
#
#   Marketing Information Country of Origin    UNSPSC  ...  Density  \
# ...

# %%
df_Gfk7 = pd.read_excel(data_path +"/" +"GFKProducts_006_2022_11_09_17_16_22.xlsx")
df_Gfk7.head()
# Out:
#     ProductID             Manufacturer Manufacturer Part Number  \
# 0  1022551437  Battery Technology, Inc             LTBT26158M2R
# 1  1022542922  Battery Technology, Inc             LTBT20182M2R
# 2  1022534673  Battery Technology, Inc             LTBT12605M2R
# 3  1022535408  Battery Technology, Inc             LTBT13543M2R
# 4  1022554893  Battery Technology, Inc             LTBT29614M2R
#
#   Manufacturer Website Address Brand Name Product Model      Product Name  \
# 0   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 1   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 2   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 3   http://www.batterytech.com        BTI           NaN  Notebook Battery
# 4   http://www.batterytech.com        BTI           NaN  Notebook Battery
#
#   Marketing Information Country of Origin    UNSPSC  ...  Density  \
# ...

# %%
df_Gfk8 = pd.read_excel(data_path +"/" +"GFKProducts_007_2022_11_09_17_16_22.xlsx")
df_Gfk8.head()
# Out:
#     ProductID               Manufacturer Manufacturer Part Number  \
# 0  1024861407  Arclyte Technologies, Inc                 MPB03622
# 1  1025006622       XCell Power Porducts                  40Y8321
# 2  1024861406  Arclyte Technologies, Inc                 MPB03620
# 3  1024808339           Shop For Battery                SFB057995
# 4  1025006631       XCell Power Porducts                 312-0383
#
#          Manufacturer Website Address        Brand Name Product Model  \
# 0                  http://arclyte.com           Arclyte           NaN
# 1  http://www.excelpowerproducts.com/             Poder        PBL520
# 2                  http://arclyte.com           Arclyte           NaN
# 3       http://www.shopforbattery.com  Shop For Battery           NaN
# 4  http://www.excelpowerproducts.com/             Poder        PBD209
#
#                                         Product Name  \
# 0                                 Cell Phone Battery
# ...

# %%
df_Gfk9 = pd.read_excel(data_path +"/" +"GFKProducts_008_2022_11_09_17_16_22.xlsx")
df_Gfk9.head()
# Out:
#     ProductID                  Manufacturer Manufacturer Part Number  \
# 0  1064077848            eReplacements, LLC               42T4518-ER
# 1  1063214213  Honeywell International, Inc              99EX-BTEC-3
# 2  1064311611             Dell Technologies                 451-BBZP
# 3  1064287688          Lenovo - Open Source                  45N1755
# 4  1064287624          Lenovo - Open Source                  00HW029
#
#       Manufacturer Website Address            Brand Name Product Model  \
# 0     http://www.ereplacements.com         eReplacements           NaN
# 1         http://www.honeywell.com             Honeywell           NaN
# 2  http://www.delltechnologies.com                  Dell           NaN
# 3        http://www.imsourcing.com  Lenovo - Open Source           NaN
# 4        http://www.imsourcing.com  Lenovo - Open Source           NaN
#
#   Product Name                              Marketing Information  \
# ...

# %%
df_Gfk10 = pd.read_excel(data_path +"/" +"GFKProducts_009_2022_11_09_17_16_22.xlsx")
df_Gfk10.head()
# Out:
#     ProductID                       Manufacturer Manufacturer Part Number  \
# 0  1019395436  SOG Specialty Knives & Tools, LLC                    FSA-5
# 1  1019366415   Columbia River Knife & Tool, Inc                     5660
# 2  1019366264                              Boker                120543DES
# 3  1019366370   Columbia River Knife & Tool, Inc                     3075
# 4  1019365702                              Boker                  01BO047
#
#   Manufacturer Website Address  Brand Name Product Model  \
# 0     http://www.sogknives.com         SOG         FSA-5
# 1          http://www.crkt.com        CRKT           NaN
# 2          http://www.boker.de       Boker           NaN
# 3          http://www.crkt.com        CRKT           NaN
# 4          http://www.boker.de  Boker Plus       01BO047
#
#                    Product Name  \
# 0   Flash II FSA-5 Pocket Knife
# 1  K.I.S.S.ASSist Hunting Knife
# 2        AF Desert Pocket Knife
# 3    Surf 'N Turf Hunting Knife
# ...

# %% [markdown]
# # 4) Find the unique UNSPSC in each Gfk file

# %%
df_Gfk1[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     Kar's Roasted & Salted Sunflower Kernels - Glu...  10151904
# 1     Starbucks Gourmet Hot Cocoa - Powder - 1.25 oz...  10152054
# 2     Swiss Miss Milk Chocolate No Sugar Added Cocoa...  10152054
# 3     Swiss Miss Milk Chocolate Hot Cocoa Mix Packet...  10152054
# 4     Nestle Carnation Hot Cocoa Mix - Powder - 0.50...  10152054
# ...                                                 ...       ...
# 9995  PowerGenix F1-0024 General Purpose Battery - F...  26111701
# 9996  Agptek Notebook Battery - For Notebook - Batte...  26111701
# 9997  Klein BLACKBOX-HCB Radio Battery - For Radio -...  26111701
# 9998  Lenovo 51J0398 Lithium Ion Notebook Battery - ...  26111701
# 9999  UltraLast Green UL-UR121 Digital Camera Batter...  26111701
#
# [10000 rows x 2 columns]

# %%
a = df_Gfk1['UNSPSC'].unique()
print(sorted(a))
# Out:
# [10151904, 10152054, 10191509, 14111801, 26111701]

# %%
df_Gfk1['UNSPSC'].value_counts()
# Out:
# 26111701    9881
# 14111801      61
# 10191509      30
# 10152054      27
# 10151904       1
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # --------------------------------------------------

# %%
df_Gfk2[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     Agptek Acer Aspire One 10.1 inch AOD150 AOD250...  26111701
# 1     BTI Notebook Battery - Lithium Ion (Li-Ion) - ...  26111701
# 2     Agptek Lenovo IBM ThinkPad R61 R61i T61 T61p R...  26111701
# 3     Axiom Ultra Bay Notebook Battery - Lithium Pol...  26111701
# 4     Miccus ChargeBlock External Battery Pack for i...  26111701
# ...                                                 ...       ...
# 9995  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9996  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9997  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9998  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9999  BTI Notebook Battery - For Notebook - Battery ...  26111701
#
# [10000 rows x 2 columns]

# %%
df_Gfk2['UNSPSC'].unique()
# Out:
# array([26111701], dtype=int64)

# %%
df_Gfk2['UNSPSC'].value_counts()
# Out:
# 26111701    10000
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # ------------------------------------------------

# %%
df_Gfk3[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 1     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 2     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 3     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 4     BTI Notebook Battery - For Notebook - Battery ...  26111701
# ...                                                 ...       ...
# 9995  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9996  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9997  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9998  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9999  BTI Notebook Battery - For Notebook - Battery ...  26111701
#
# [10000 rows x 2 columns]

# %%
df_Gfk3['UNSPSC'].unique()
# Out:
# array([26111701], dtype=int64)

# %%
df_Gfk3['UNSPSC'].value_counts()
# Out:
# 26111701    10000
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # -----------------------------------------------------------

# %%
df_Gfk4[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 1     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 2     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 3     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 4     BTI Notebook Battery - For Notebook - Battery ...  26111701
# ...                                                 ...       ...
# 9995  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9996  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9997  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9998  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9999  BTI Notebook Battery - For Notebook - Battery ...  26111701
#
# [10000 rows x 2 columns]

# %%
df_Gfk4['UNSPSC'].unique()
# Out:
# array([26111701], dtype=int64)

# %%
df_Gfk4['UNSPSC'].value_counts()
# Out:
# 26111701    10000
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # ----------------------------------------------------------

# %%
df_Gfk5[['Description', 'UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 1     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 2     BTI Netbook Battery - For Netbook - Battery Re...  26111701
# 3     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 4     BTI Notebook Battery - For Notebook - Battery ...  26111701
# ...                                                 ...       ...
# 9995  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9996  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9997  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9998  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9999  BTI Notebook Battery - For Notebook - Battery ...  26111701
#
# [10000 rows x 2 columns]

# %%
df_Gfk5['UNSPSC'].unique()
# Out:
# array([26111701], dtype=int64)

# %%
df_Gfk5['UNSPSC'].value_counts()
# Out:
# 26111701    10000
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # ----------------------------------------------------------

# %%
df_Gfk6[['Description', 'UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 1     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 2     BTI Netbook Battery - For Netbook - Battery Re...  26111701
# 3     BTI Netbook Battery - For Netbook - Battery Re...  26111701
# 4     BTI Notebook Battery - For Notebook - Battery ...  26111701
# ...                                                 ...       ...
# 9995  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9996  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9997  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9998  BTI Notebook Battery - For Notebook - Battery ...  26111701
# 9999  BTI Notebook Battery - For Notebook - Battery ...  26111701
#
# [10000 rows x 2 columns]

# %%
df_Gfk6['UNSPSC'].unique()
# Out:
# array([26111701], dtype=int64)

# %%
df_Gfk6['UNSPSC'].value_counts()
# Out:
# 26111701    10000
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # ---------------------------------------------------------------

# %%
df_Gfk7[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 1     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 2     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 3     BTI Notebook Battery - For Notebook - Battery ...  26111701
# 4     BTI Notebook Battery - For Notebook - Battery ...  26111701
# ...                                                 ...       ...
# 9995  UPG ADVENTURE POWER 6UB11-2D Automotive Batter...  26111701
# 9996  Battery Biz Notebook Battery - For Notebook - ...  26111701
# 9997  Poder 6 Cell Poder Battery for IBM Lenovo Idea...  26111701
# 9998  Poder Notebook Battery - For Notebook - Batter...  26111701
# 9999  truCELL CB-P101 Cordless Phone Battery - For C...  26111701
#
# [10000 rows x 2 columns]

# %%
df_Gfk7['UNSPSC'].unique()
# Out:
# array([26111701], dtype=int64)

# %%
df_Gfk7['UNSPSC'].value_counts()
# Out:
# 26111701    10000
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # -----------------------------------------------------------------

# %%
df_Gfk8[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     Arclyte Motorola Batt ATRIX 2; Droid Bionic XT...  26111701
# 1     Poder 6 Cell Poder Battery for IBM Lenovo 3000...  26111701
# 2     Arclyte HTC Batt Droid Thunderbolt; Incredible...  26111701
# 3     Shop For Battery Notebook Battery - For Notebo...  26111701
# 4     Poder 6 Cell Poder Battery for Dell Latitude D...  26111701
# ...                                                 ...       ...
# 9995  Lenovo - Open Source Battery - For Notebook - ...  26111701
# 9996  Vivanco BP-I 2507LS Digital Camcorder Battery ...  26111701
# 9997  Lenovo - Open Source Battery - For Notebook - ...  26111701
# 9998  White Energy Notebook Battery - For Notebook -...  26111701
# 9999  Lenovo Battery - For Notebook - Battery Rechar...  26111701
#
# [10000 rows x 2 columns]

# %%
df_Gfk8['UNSPSC'].unique()
# Out:
# array([26111701], dtype=int64)

# %%
df_Gfk8['UNSPSC'].value_counts()
# Out:
# 26111701    10000
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # -------------------------------------------------------------

# %%
df_Gfk9[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     eReplacements Battery - For Notebook - Battery...  26111701
# 1     Honeywell Battery - For Mobile Computer - Batt...  26111701
# 2     Dell Battery - For Notebook - Battery Recharge...  26111701
# 3     Lenovo - Open Source Battery - For Notebook - ...  26111701
# 4     Lenovo - Open Source Battery - For Notebook - ...  26111701
# ...                                                 ...       ...
# 9995  Arbolito El Trampero Hunting Knife - Fixed Bla...  27111503
# 9996  CRKT K.I.S.S. 5510K Cutting Knife - Folding Kn...  27111503
# 9997  Boker Mach 2 Hunting Knife - Fixed Blade Knife...  27111503
# 9998  SOG Toothlock TK-01 Pocket Knife - Folding Poc...  27111503
# 9999  Boker Stag II Pocket Knife - Folding Pocket Kn...  27111503
#
# [10000 rows x 2 columns]

# %%
b = df_Gfk9['UNSPSC'].unique()
print(sorted(b))
# Out:
# [26111700, 26111701, 26111702, 26111707, 26111710, 26111711, 26111714, 26111718, 27111503]

# %%
df_Gfk9['UNSPSC'].value_counts()
# Out:
# 26111707    1949
# 27111503    1829
# 26111702    1501
# 26111701    1460
# 26111710    1452
# 26111700    1190
# 26111711     400
# 26111718     159
# 26111714      60
# Name: UNSPSC, dtype: int64

# %% [markdown]
# # -------------------------------------------------------

# %%
df_Gfk10[['Description','UNSPSC']]
# Out:
#                                             Description    UNSPSC
# 0     SOG Flash II FSA-5 Pocket Knife - Folding Pock...  27111503
# 1     CRKT K.I.S.S.ASSist Hunting Knife - Folding Kn...  27111503
# 2     Boker AF Desert Pocket Knife - Folding Pocket ...  27111503
# 3     CRKT Surf 'N Turf Hunting Knife - Folding Knif...  27111503
# 4     Boker Plus Urban Survival Pocket Knife - Foldi...  27111503
# ...                                                 ...       ...
# 7881  Fiskars Heavy-duty Die-cast Craft Knife - Mult...  60121304
# 7882  ArtSkills Poster Knife - Foam Board, Poster Bo...  60121304
# 7883  cricut TrueControl Kit, Mint - Paper, Card Sto...  60121304
# 7884  cricut TrueControl Knife, Blue - Paper, Card S...  60121304
# 7885  Canon eCarePAK - Extended Warranty - 2 Year - ...  64121514
#
# [7886 rows x 2 columns]

# %%
c = df_Gfk10['UNSPSC'].unique()
print(sorted(c))
# Out:
# [24111500, 27111503, 27111504, 42131602, 42131612, 42131713, 42132102, 42132203, 42142301, 42142609, 42142901, 42142902, 42142905, 42142907, 42172001, 42172002, 42172010, 42172101, 42182103, 42182201, 42182205, 42182603, 42190000, 42192001, 42192404, 42201810, 42231806, 42271709, 42293515, 42295473, 42301502, 42311552, 44111601, 44121604, 46101506, 46101801, 46101903, 46161508, 50101717, 50102512, 50102516, 51143103, 51161812, 51162304, 51162402, 51171501, 51312304, 51313101, 60101711, 60101909, 60103933, 60106208, 60121001, 60121006, 60121008, 60121012, 60121013, 60121304, 64121514]

# %%
df_Gfk10['UNSPSC'].value_counts()
# Out:
# 27111503    1612
# 42142905    1149
# 42192404     751
# 46101506     650
# 42132203     572
# 42142901     535
# 44121604     467
# 60121012     452
# 27111504     335
# 42172001     328
# 60121008     282
# 46101801     250
# 42142301     180
# 44111601     111
# 42142902      22
# 42142609      16
# 46161508      15
# 42182201      13
# 42293515      12
# 24111500      11
# 42192001      11
# 60121304       9
# 60103933       9
# 42172101       8
# 42311552       8
# 46101903       7
# 42131602       5
# 42271709       5
# 42182603       5
# 42182205       5
# 42182103       5
# 60121013       5
# 42131713       5
# 51143103       3
# 50102516       2
# 51161812       2
# 60101909       2
# 42131612       2
# 60121001       2
# 51312304       2
# 42172010       2
# 42132102       2
# 60106208       1
# 60121006       1
# 60101711       1
# 51313101       1
# 42301502       1
# 51171501       1
# 51162402       1
# 51162304       1
# 50102512       1
# 50101717       1
# ...

# %%
pd.Series(c).sort_values()
# Out:
# 32    24111500
# 0     27111503
# 1     27111504
# 2     42131602
# 3     42131612
# 4     42131713
# 5     42132102
# 6     42132203
# 7     42142301
# 8     42142609
# 9     42142901
# 10    42142902
# 11    42142905
# 12    42142907
# 13    42172001
# 14    42172002
# 15    42172010
# 16    42172101
# 17    42182103
# 18    42182201
# 19    42182205
# 21    42182603
# 20    42190000
# 22    42192001
# 23    42192404
# 24    42201810
# 25    42231806
# 26    42271709
# 27    42293515
# 28    42295473
# 29    42301502
# 30    42311552
# 31    44111601
# 33    44121604
# 34    46101506
# 35    46101801
# 36    46101903
# 37    46161508
# 38    50101717
# 39    50102512
# 40    50102516
# 41    51143103
# 42    51161812
# 43    51162304
# 44    51162402
# 45    51171501
# 46    51312304
# 47    51313101
# 48    60101711
# 49    60101909
# 50    60103933
# 51    60106208
# 52    60121001
# 53    60121006
# 54    60121008
# 55    60121012
# 56    60121013
# 57    60121304
# ...

# %% [markdown]
# # 5) Initialize the Input and Output variables

# %%
output = 'UNSPSC'
y = df_Gfk1[output]
features = ['Description']
X = df_Gfk1[features]
X.head()
# Out:
#                                          Description
# 0  Kar's Roasted & Salted Sunflower Kernels - Glu...
# 1  Starbucks Gourmet Hot Cocoa - Powder - 1.25 oz...
# 2  Swiss Miss Milk Chocolate No Sugar Added Cocoa...
# 3  Swiss Miss Milk Chocolate Hot Cocoa Mix Packet...
# 4  Nestle Carnation Hot Cocoa Mix - Powder - 0.50...

# %% [markdown]
# # 6) Download the stopwords from NLTK

# %%
import nltk
nltk.download()  # Download text data sets, including stop words
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import re

from nltk.corpus import stopwords # Import the stop word list

def description_to_words(review_text):
    
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text)
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
clean_review = description_to_words(df_Gfk1['Description'][1] )
print(clean_review)
# Out:
# starbucks gourmet hot cocoa powder oz box

# %%
# Get the number of reviews based on the dataframe column size
num_description = df_Gfk1['Description'].size
print("Cleaning and parsing the training set UNSPSC description...\n")
clean_description = []
for i in range(0, num_description):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print("Description %d of %d\n" % ( i+1, num_description))                                                                  
    clean_description.append(description_to_words(df_Gfk1['Description'][i] ))
# Out:
# Cleaning and parsing the training set UNSPSC description...
#
# Description 1000 of 10000
#
# Description 2000 of 10000
#
# Description 3000 of 10000
#
# Description 4000 of 10000
#
# Description 5000 of 10000
#
# Description 6000 of 10000
#
# Description 7000 of 10000
#
# Description 8000 of 10000
#
# Description 9000 of 10000
#
# Description 10000 of 10000

# %% [markdown]
# # 7) Printing the list containing the useful words extracted from the training dataset

# %%
print(clean_description[:50])
# Out:
# ['kar roasted salted sunflower kernels gluten free roasted salted oz box', 'starbucks gourmet hot cocoa powder oz box', 'swiss miss milk chocolate sugar added cocoa mix packets powder oz box', 'swiss miss milk chocolate hot cocoa mix packets powder oz box', 'nestle carnation hot cocoa mix powder oz box', 'nestle rich hot cocoa mix powder oz box', 'green mountain coffee roasters hot cocoa chocolate k cup box', 'green mountain coffee roasters hot cocoa k cup chocolate k cup box', 'flavia indulgent creations choco oz box', 'swiss miss regular hot chocolate mix powder oz box', 'flavia dove premium hot chocolate oz box', 'swiss miss hot chocolate marshmallows chocolate oz powder box', 'swiss miss sugar free hot cocoa chocolate oz box', 'timothy white hot chocolate k cup chocolate box', 'swiss miss regular hot chocolate envelope chocolate oz powder box', 'gloria jean hot chocolate chocolate k cup box', 'swiss miss marshmllow lovers hot chocolate powder oz carton', 'nestle hot cocoa whipper
# ...

# %% [markdown]
# # 8) Creating bag of words from the useful word extraction

# %%
print("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",tokenizer = None,preprocessor = None,stop_words = None,max_features = 5000) 
train_data_features = vectorizer.fit_transform(clean_description)
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
print(train_data_features.shape)
# Out:
# (10000, 2055)

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names_out()
print(vocab)
# Out:
# ['aa' 'aaa' 'aaem' ... 'zr' 'zt' 'zylight']

# %%
each = np.sum(train_data_features, axis=0)
print(each)
# Out:
# [240  95   1 ...   1   2   1]

# %% [markdown]
# # 9) Training the model using Random Forest

# %%
import time

print("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
start = time.time()
# This may take a few minutes to run
forest = forest.fit( train_data_features, df_Gfk1['UNSPSC'] )
end = time.time() 

total = end - start

print("Total time taken to train the model is ", total)
# Out:
# Training the random forest...
# Total time taken to train the model is  10.233049154281616

# %% [markdown]
# # 10) Repeat the process for 2nd GFK file

# %%
# Initialize the Input and Output variables
output = 'UNSPSC'
y = df_Gfk2[output]
features = ['Description']
X = df_Gfk2[features]
X.head()
# Out:
#                                          Description
# 0  Agptek Acer Aspire One 10.1 inch AOD150 AOD250...
# 1  BTI Notebook Battery - Lithium Ion (Li-Ion) - ...
# 2  Agptek Lenovo IBM ThinkPad R61 R61i T61 T61p R...
# 3  Axiom Ultra Bay Notebook Battery - Lithium Pol...
# 4  Miccus ChargeBlock External Battery Pack for i...

# %%
# Extract the meaningful words
clean_review = description_to_words(df_Gfk2['Description'][3] )
print(clean_review)
# Get the number of reviews based on the dataframe column size
num_description = df_Gfk2['Description'].size
print("Cleaning and parsing the training set UNSPSC description...\n")
clean_description = []
for i in range(0, num_description):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print("Description %d of %d\n" % ( i+1, num_description))                                                                  
    clean_description.append(description_to_words(df_Gfk2['Description'][i] ))
# Printing the list containing the useful words extracted from the training dataset
print(clean_description[:50])

# Creating bag of words from the useful word extraction
print("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",tokenizer = None,preprocessor = None,stop_words = None,max_features = 5000) 
train_data_features = vectorizer.fit_transform(clean_description)
train_data_features = train_data_features.toarray()

print(train_data_features.shape)

# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names_out()
print(vocab)
each = np.sum(train_data_features, axis=0)
print(each)

# Training the model using Random Forest
import time

print("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
start = time.time()
# This may take a few minutes to run
forest = forest.fit( train_data_features, df_Gfk2['UNSPSC'] )
end = time.time() 

total = end - start

print("Total time taken to train the model is ", total)
# Out:
# axiom ultra bay notebook battery lithium polymer li polymer
# Cleaning and parsing the training set UNSPSC description...
#
# Description 1000 of 10000
#
# Description 2000 of 10000
#
# Description 3000 of 10000
#
# Description 4000 of 10000
#
# Description 5000 of 10000
#
# Description 6000 of 10000
#
# Description 7000 of 10000
#
# Description 8000 of 10000
#
# Description 9000 of 10000
#
# Description 10000 of 10000
#
# ...

# %% [markdown]
# # 11) 3rd GFK file

# %%
# Initialize the Input and Output variables
output = 'UNSPSC'
y = df_Gfk3[output]
features = ['Description']
X = df_Gfk3[features]
X.head()
# Out:
#                                          Description
# 0  BTI Notebook Battery - For Notebook - Battery ...
# 1  BTI Notebook Battery - For Notebook - Battery ...
# 2  BTI Notebook Battery - For Notebook - Battery ...
# 3  BTI Notebook Battery - For Notebook - Battery ...
# 4  BTI Notebook Battery - For Notebook - Battery ...

# %%
# Extract the meaningful words
clean_review = description_to_words(df_Gfk3['Description'][3] )
print(clean_review)
# Get the number of reviews based on the dataframe column size
num_description = df_Gfk3['Description'].size
print("Cleaning and parsing the training set UNSPSC description...\n")
clean_description = []
for i in range(0, num_description):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print("Description %d of %d\n" % ( i+1, num_description))                                                                  
    clean_description.append(description_to_words(df_Gfk3['Description'][i] ))
# Printing the list containing the useful words extracted from the training dataset
print(clean_description[:50])

# Creating bag of words from the useful word extraction
print("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",tokenizer = None,preprocessor = None,stop_words = None,max_features = 5000) 
train_data_features = vectorizer.fit_transform(clean_description)
train_data_features = train_data_features.toarray()

print(train_data_features.shape)

# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names_out()
print(vocab)
each = np.sum(train_data_features, axis=0)
print(each)

# Training the model using Random Forest
import time

print("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
start = time.time()
# This may take a few minutes to run
forest = forest.fit( train_data_features, df_Gfk3['UNSPSC'] )
end = time.time() 

total = end - start

print("Total time taken to train the model is ", total)
# Out:
# bti notebook battery notebook battery rechargeable mah
# Cleaning and parsing the training set UNSPSC description...
#
# Description 1000 of 10000
#
# Description 2000 of 10000
#
# Description 3000 of 10000
#
# Description 4000 of 10000
#
# Description 5000 of 10000
#
# Description 6000 of 10000
#
# Description 7000 of 10000
#
# Description 8000 of 10000
#
# Description 9000 of 10000
#
# Description 10000 of 10000
#
# ...
